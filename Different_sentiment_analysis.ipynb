# %%
#pip install textblob
#pip install vaderSentiment
#pip install transformers
# !pip install torch
# Out:
# ...
#    ---------------------------------------- 0.0/204.1 MB ? eta -:--:--
#    ---------------------------------------- 0.3/204.1 MB 7.1 MB/s eta 0:00:29
#    ---------------------------------------- 0.4/204.1 MB 4.6 MB/s eta 0:00:45
#    ---------------------------------------- 0.5/204.1 MB 3.7 MB/s eta 0:00:55
#    ---------------------------------------- 0.8/204.1 MB 4.4 MB/s eta 0:00:47
#    ---------------------------------------- 1.3/204.1 MB 5.5 MB/s eta 0:00:38
#    ---------------------------------------- 1.8/204.1 MB 6.3 MB/s eta 0:00:32
#    ---------------------------------------- 2.4/204.1 MB 7.3 MB/s eta 0:00:28
#     --------------------------------------- 3.0/204.1 MB 8.2 MB/s eta 0:00:25
#     --------------------------------------- 3.7/204.1 MB 8.7 MB/s eta 0:00:23
#     --------------------------------------- 4.1/204.1 MB 8.8 MB/s eta 0:00:23
#    - -------------------------------------- 5.2/204.1 MB 9.9 MB/s eta 0:00:21
# ...

# %%
from textblob import TextBlob
text = "I had only 1 bag with me, a carry on trolley.Everyone one in boarding group 3 & 4 were forced to check-in their trolley carry-ons. They asked to take out any laptops, batteries, etc.... The woman at the boarding gate was very rude to me as I was explaining to her that this was my only bag and had nowhere to carry my laptop or other stuff that I need onboard. I tried to explain to her that the bag will not withstand being carried in the hold as it is fragile and showed her a crack from the one time I checked it in before. The bag was visibly small complying with the carry-on bag measurements."
blob = TextBlob(text)
senti = blob.sentiment
print(text)
print(f"polarity {senti.polarity:.2f} , Subjectivity : {senti.subjectivity:.2f}")
# Out:
# I had only 1 bag with me, a carry on trolley.Everyone one in boarding group 3 & 4 were forced to check-in their trolley carry-ons. They asked to take out any laptops, batteries, etc.... The woman at the boarding gate was very rude to me as I was explaining to her that this was my only bag and had nowhere to carry my laptop or other stuff that I need onboard. I tried to explain to her that the bag will not withstand being carried in the hold as it is fragile and showed her a crack from the one time I checked it in before. The bag was visibly small complying with the carry-on bag measurements.
# polarity -0.15 , Subjectivity : 0.61

# %% [markdown]
# # VADER(Valence Aware Dictionary and Sentiment Reasoner)

# %%
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
analyzer = SentimentIntensityAnalyzer()
scores = analyzer.polarity_scores(text)
print(text)
print(f"scores : {scores}\n")
print(f"A Normalized weighted score between -1(most negative) to +1(most positive) : {scores['compound']} summerzing the overall sentiments ")
# Out:
# I had only 1 bag with me, a carry on trolley.Everyone one in boarding group 3 & 4 were forced to check-in their trolley carry-ons. They asked to take out any laptops, batteries, etc.... The woman at the boarding gate was very rude to me as I was explaining to her that this was my only bag and had nowhere to carry my laptop or other stuff that I need onboard. I tried to explain to her that the bag will not withstand being carried in the hold as it is fragile and showed her a crack from the one time I checked it in before. The bag was visibly small complying with the carry-on bag measurements.
# scores : {'neg': 0.052, 'neu': 0.948, 'pos': 0.0, 'compound': -0.7425}
#
# A Normalized weighted score between -1(most negative) to +1(most positive) : -0.7425 summerzing the overall sentiments

# %%
'''from transformers import pipeline
senti_pipe = pipeline("sentiment-analysis")
res = senti_pipe(text)[0]
print(text)
print(res['label'])'''
# Out:
# 'from transformers import pipeline\nsenti_pipe = pipeline("sentiment-analysis")\nres = senti_pipe(text)[0]\nprint(text)\nprint(res[\'label\'])'

# %%
len(text.split())
# Out:
# 117
